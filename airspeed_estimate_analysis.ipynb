# %%
from px4tools import logdynamicpressure as ldp
import numpy as np
from bokeh.plotting import figure, output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e9030c2-ca2e-4610-b1b2-7e53504f465c">Loading BokehJS ...</span>
#     </div>

# %%
file = 'log/12_52_01.ulg'

# %%
# load data and do airspeed estimation
df = ldp.load_data(file)
df = ldp.estimate_airspeed(df)

# %%
p_global = figure(title='airspeed global',plot_width = 800, plot_height = 500 )
p_body = figure(title='airspeed body',plot_width = 800, plot_height = 500 )
p_mag = figure(title='airspeed magnitude',plot_width = 800, plot_height = 500 )

# %%
p_global.line(df.index, df.t_vehicle_local_position_0__f_vx, color = 'red', legend='v_x',line_width = 2)
p_global.line(df.index, df.t_vehicle_altitude_hold_0__f_v_airx, color = 'black', legend='v_air_x',line_width = 2)
p_global.line(df.index, df.t_vehicle_local_position_0__f_vy, color = 'orange', legend='v_y',line_width = 2)
p_global.line(df.index, df.t_vehicle_altitude_hold_0__f_v_airy, color = 'blue', legend='v_air_y',line_width = 2)
# Out:
# GlyphRenderer(id='aa1c4899-de01-4344-a984-c38aca260868', ...)

# %%
show(p_global, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2ef7c602-0a0c-4892-972a-d8aab2968c2e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2ef7c602-0a0c-4892-972a-d8aab2968c2e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("23aa1d9b-dd33-438d-afe2-5b6ef33092f9", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2ef7c602-0a0c-4892-972a-d8aab2968c2e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2ef7c602-0a0c-4892-972a-d8aab2968c2e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6731cf38-b371-4fd3-b35d-55db1cd2f683":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fe7459e1-9cf1-46c9-8ac9-bc6b2a91f066","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3261a153-9758-4393-b020-ed22beb1d4c3","type":"Line"},{"attributes":{},"id":"64608364-9b2c-416e-9a01-224f05f67283","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e79c3196-94e4-417a-8d30-20fa212ecc06","type":"PanTool"},{"id":"9b05d7ab-6557-4b4b-9f12-357c1f971784","type":"WheelZoomTool"},{"id":"8f3c6fc6-9a66-4959-a0a1-71e8f692c27b","type":"BoxZoomTool"},{"id":"01d7178b-b700-49a2-b240-c199979585e0","type":"SaveTool"},{"id":"0bc9ef3e-fb28-446a-8f3e-dd618d848b68","type":"ResetTool"},{"id":"6fc01c35-7885-4a0b-bc0c-ab7e4e3bf97a","type":"HelpTool"}]},"id":"89b71898-24a4-4613-8c30-db2e197b50e2","type":"Toolbar"},{"attributes":{"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"}},"id":"6fc01c35-7885-4a0b-bc0c-ab7e4e3bf97a","type":"HelpTool"},{"attributes":{"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"}},"id":"0bc9ef3e-fb28-446a-8f3e-dd618d848b68","type":"ResetTool"},{"attributes":{"overlay":{"id":"2f432fb4-caf3-49be-99e9-c13d81ff146a","type":"BoxAnnotation"},"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"}},"id":"8f3c6fc6-9a66-4959-a0a1-71e8f692c27b","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"airspeed global"},"id":"01319931-a878-49c1-a2b7-a5bcc974284d","type":"Title"},{"attributes":{"formatter":{"id":"49660bb6-7224-417a-947a-66addf06618d","type":"BasicTickFormatter"},"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"},"ticker":{"id":"8e75d0ce-2cc9-4bd3-b845-4957a3a8d253","type":"BasicTicker"}},"id":"7cacaa6e-adb9-4002-816d-066f5e2860a7","type":"LinearAxis"},{"attributes":{},"id":"8e75d0ce-2cc9-4bd3-b845-4957a3a8d253","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6eaf0422-e621-43a0-ab36-9985cb7dee2f","type":"ColumnDataSource"},"glyph":{"id":"5d4e8ae5-f5ce-4846-8153-066928b935db","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ba10e6e1-4dce-4367-b692-11ebdb346780","type":"Line"},"selection_glyph":null},"id":"aa1c4899-de01-4344-a984-c38aca260868","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f20bc36-0cdd-4038-b413-a1da7f9048b4","type":"Line"},{"attributes":{"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"},"ticker":{"id":"8e75d0ce-2cc9-4bd3-b845-4957a3a8d253","type":"BasicTicker"}},"id":"a76cbb97-4a4c-4cc5-9a6c-649213e158d3","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float32","shape":[569]}}},"id":"1e289285-9582-4813-9d4d-f14c985b1db6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float32","shape":[569]}}},"id":"c4ff8440-8f4d-4d0a-9cd5-1996fa23cc21","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"95c53e1f-3ac5-4c48-b5ff-84410aa348f3","type":"DataRange1d"},{"attributes":{"formatter":{"id":"64608364-9b2c-416e-9a01-224f05f67283","type":"BasicTickFormatter"},"plot":{"id":"3998fd47-27d5-46ba-ac3a-f09d7b3e5db5","subtype":"Figure","type":"Plot"},"ticker":{"id":"54a6c57b-9585-4f56-9c0f-b701359e217f","type":"BasicTicker"}},"id":"39d8d38b-e406-4b29-b957-605b126fefdb","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[56]</strong>&gt;</code></p>

# %%
p_body.line(df.index, df.t_vehicle_local_position_0__f_vx_body, color = 'red', legend='v_x_body',line_width = 2)
p_body.line(df.index, df.t_vehicle_altitude_hold_0__f_v_airx_body, color = 'black', legend='v_air_x_body',line_width = 2)
p_body.line(df.index, df.t_vehicle_local_position_0__f_vy_body, color = 'orange', legend='v_y_body',line_width = 2)
p_body.line(df.index, df.t_vehicle_altitude_hold_0__f_v_airy_body, color = 'blue', legend='v_air_y_body',line_width = 2)
# Out:
# GlyphRenderer(id='36bde4ea-de36-4027-978f-6058dad992e6', ...)

# %%
show(p_body, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="23fc6362-17a3-4f01-85fb-04517e96353d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("23fc6362-17a3-4f01-85fb-04517e96353d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("35bc330c-e1b0-4cd4-a46f-d515856fc632", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("23fc6362-17a3-4f01-85fb-04517e96353d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '23fc6362-17a3-4f01-85fb-04517e96353d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2556eef1-7c69-4adf-a714-e61fbb4d69c9":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b366753-f4ae-4b1d-a616-a4182e000156","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"afb90f39-5c20-4c45-9097-df83ed6514ce","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float64","shape":[569]}}},"id":"4fadf8d7-4696-424c-8568-d2c33234ce9e","type":"ColumnDataSource"},{"attributes":{},"id":"ee022646-7df5-4a39-af31-96cea88de10b","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"v_x_body"},"renderers":[{"id":"0d796eb5-c576-4250-84de-a6e88f50d955","type":"GlyphRenderer"}]},"id":"f1fd662f-a7c1-4bfe-983a-2067d3a2452e","type":"LegendItem"},{"attributes":{"plot":{"id":"9aef7fcc-f1e7-402a-a4c4-d327f691fe5c","subtype":"Figure","type":"Plot"}},"id":"727e2f49-c099-458c-a1f5-ac1595ebd835","type":"ResetTool"},{"attributes":{"overlay":{"id":"4dfa5f23-da6f-40ee-a328-14a510b1352e","type":"BoxAnnotation"},"plot":{"id":"9aef7fcc-f1e7-402a-a4c4-d327f691fe5c","subtype":"Figure","type":"Plot"}},"id":"797bfd20-03d9-457e-812d-df2b1cf560ec","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float64","shape":[569]}}},"id":"128168e2-6a5d-48ff-9047-00865c2c8b55","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float64","shape":[569]}}},"id":"d64370b8-e070-43ad-8e17-840daa8867e2","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0257a5ae-3e31-44e3-bded-6e496ec4caab","type":"PanTool"},{"id":"9bca9bbf-c07c-4078-ad6e-bba21c4607e8","type":"WheelZoomTool"},{"id":"797bfd20-03d9-457e-812d-df2b1cf560ec","type":"BoxZoomTool"},{"id":"18f1edd0-facc-476e-8d2a-befe5fd5343c","type":"SaveTool"},{"id":"727e2f49-c099-458c-a1f5-ac1595ebd835","type":"ResetTool"},{"id":"021fe6ef-3698-4e72-acac-d781c8a015f1","type":"HelpTool"}]},"id":"7249bf54-97bc-411c-adcd-593ec4f1326b","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1931ca57-0fe9-496b-9b89-37fec8520722","type":"Line"},{"attributes":{"plot":{"id":"9aef7fcc-f1e7-402a-a4c4-d327f691fe5c","subtype":"Figure","type":"Plot"}},"id":"0257a5ae-3e31-44e3-bded-6e496ec4caab","type":"PanTool"},{"attributes":{"plot":{"id":"9aef7fcc-f1e7-402a-a4c4-d327f691fe5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3e5b4f8-483f-4843-befc-90797e2a921a","type":"BasicTicker"}},"id":"4fb1281f-019e-4337-a01f-7126c56cc161","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"cb278beb-ab8a-45b1-87be-344a633e1d7e","type":"Line"},{"attributes":{"callback":null},"id":"b61e5ce8-7b26-44ec-89c9-6ad293eec038","type":"DataRange1d"},{"attributes":{"data_source":{"id":"6c5ba8f5-375c-45d3-8cef-a2f68655d9f8","type":"ColumnDataSource"},"glyph":{"id":"5073c30d-8b8d-44bc-9c49-b8bdb2605c1c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9b366753-f4ae-4b1d-a616-a4182e000156","type":"Line"},"selection_glyph":null},"id":"cdaa1bd0-a596-45f2-b9b2-26dc32f3daa4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"128168e2-6a5d-48ff-9047-00865c2c8b55","type":"ColumnDataSource"},"glyph":{"id":"48b047c4-9419-41b8-b1f9-b8f32efb11bc","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"afb90f39-5c20-4c45-9097-df83ed6514ce","type":"Lin ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[58]</strong>&gt;</code></p>

# %%
p_mag.line(df.index, np.sqrt(df.t_vehicle_local_position_0__f_vx**2 + 
                             df.t_vehicle_local_position_0__f_vy**2), color = 'red', legend='v_mag',line_width = 2)
p_mag.line(df.index, np.sqrt(df.t_vehicle_altitude_hold_0__f_v_airx**2 +
                             df.t_vehicle_altitude_hold_0__f_v_airy**2), color = 'black', legend='v_air_mag',line_width = 2)
# Out:
# GlyphRenderer(id='8c1605a5-228c-4c8a-b40f-be2d6281f2f6', ...)

# %%
show(p_mag, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e09e791b-8c64-4256-a054-b91185bc6d11"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e09e791b-8c64-4256-a054-b91185bc6d11").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("0134047b-4325-4e3d-a083-3084987b8f47", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e09e791b-8c64-4256-a054-b91185bc6d11");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e09e791b-8c64-4256-a054-b91185bc6d11' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6b894fff-0da1-40a8-b8e0-05a429272b21":{"roots":{"references":[{"attributes":{"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"}},"id":"80995a66-0dd9-42c4-89bd-4ef8a29f3bdb","type":"ResetTool"},{"attributes":{"formatter":{"id":"cd7e17aa-1eba-413d-93a8-884f8db342f2","type":"BasicTickFormatter"},"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"},"ticker":{"id":"40e5f96a-365e-47fa-8e4c-4cfc3754fd2e","type":"BasicTicker"}},"id":"8347cd04-3ab9-48b1-bdae-4089b05fc835","type":"LinearAxis"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d9e7b64-ff05-4b0c-befd-30f3c229a9a2","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[569]},"y":{"__ndarray__":"...","dtype":"float64","shape":[569]}}},"id":"a9c92f70-f8ab-46e6-a5ed-607d0c7b3484","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"b9b962a9-743a-4058-9188-1d2a034ad758","type":"BoxAnnotation"},"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"}},"id":"60830f17-cec4-42b0-973a-7b207c161afd","type":"BoxZoomTool"},{"attributes":{},"id":"a220171a-e126-4f83-ad0a-81d096fde126","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"},"ticker":{"id":"40e5f96a-365e-47fa-8e4c-4cfc3754fd2e","type":"BasicTicker"}},"id":"8443ec72-fc28-4d0f-b3fe-1365126acb02","type":"Grid"},{"attributes":{"label":{"value":"v_mag"},"renderers":[{"id":"b5daaf92-cf3f-4b52-9bcd-2be0765c3629","type":"GlyphRenderer"}]},"id":"bae52acc-d42e-4466-95a6-802969647e9e","type":"LegendItem"},{"attributes":{},"id":"ff6064a5-584e-42ad-91ac-b23d525c879f","type":"ToolEvents"},{"attributes":{},"id":"cd7e17aa-1eba-413d-93a8-884f8db342f2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"},"ticker":{"id":"a220171a-e126-4f83-ad0a-81d096fde126","type":"BasicTicker"}},"id":"c0ea59bd-c7f1-4d81-82e3-4846451e28e9","type":"Grid"},{"attributes":{},"id":"40e5f96a-365e-47fa-8e4c-4cfc3754fd2e","type":"BasicTicker"},{"attributes":{"plot":null,"text":"airspeed magnitude"},"id":"1617b897-015b-429a-96ec-b03ac932c666","type":"Title"},{"attributes":{"callback":null},"id":"a268f8ef-13e6-449f-9f74-f8f8a87cfe08","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b8e62223-d8e5-4050-838e-2b7efe44bfc8","type":"BasicTickFormatter"},"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"},"ticker":{"id":"a220171a-e126-4f83-ad0a-81d096fde126","type":"BasicTicker"}},"id":"77625a1b-58ea-47ea-8a97-cc14e67a2bec","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7689f0cd-0b48-428c-b6e0-edcab9c2a650","type":"PanTool"},{"id":"a0598c12-a9fd-4c44-b970-19ee32483840","type":"WheelZoomTool"},{"id":"60830f17-cec4-42b0-973a-7b207c161afd","type":"BoxZoomTool"},{"id":"8d2074b7-ba9b-407c-a198-417dee4bf20f","type":"SaveTool"},{"id":"80995a66-0dd9-42c4-89bd-4ef8a29f3bdb","type":"ResetTool"},{"id":"1d47a5c2-0351-488e-8791-e5513d440877","type":"HelpTool"}]},"id":"1d854a1d-067a-4260-986f-008717052edb","type":"Toolbar"},{"attributes":{"items":[{"id":"bae52acc-d42e-4466-95a6-802969647e9e","type":"LegendItem"},{"id":"63fed70b-b6ec-4393-aff8-c112ecc9e9fa","type":"LegendItem"}],"plot":{"id":"69c39de0-e86a-41e2-8cc2-57ca1137aaed","subtype":"Figure","type":"Plot"}},"id":"f9cc4865-fa56-4986-b6c9-90ff83d05261","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b9b962a9-743a-4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[60]</strong>&gt;</code></p>
